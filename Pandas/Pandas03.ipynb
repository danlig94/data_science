# %% [markdown]
# <a href="https://colab.research.google.com/github/danlig94/data_science/blob/master/Pandas/Pandas03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
def fetch_financial_data(company='AMZN'):
    """Download data on the listing of companies on the stock exchange by symbols
    on the site stooq.pl"""
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2020-09-02 to 2015-09-08
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df.head()
# Out:
#                Open       High       Low    Close   Volume
# Date
# 2020-09-02  3547.00  3552.2500  3486.685  3531.45  3931476
# 2020-09-01  3489.58  3513.8700  3467.000  3499.12  3476407
# 2020-08-31  3408.99  3495.0000  3405.000  3450.96  4185885
# 2020-08-28  3423.00  3433.3699  3386.500  3401.80  2896978
# 2020-08-27  3450.05  3453.0000  3378.000  3400.00  4264795

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.columns = [col.lower() for col in df.columns]
df.head()
# Out:
#                open       high       low    close   volume
# Date
# 2020-09-02  3547.00  3552.2500  3486.685  3531.45  3931476
# 2020-09-01  3489.58  3513.8700  3467.000  3499.12  3476407
# 2020-08-31  3408.99  3495.0000  3405.000  3450.96  4185885
# 2020-08-28  3423.00  3433.3699  3386.500  3401.80  2896978
# 2020-08-27  3450.05  3453.0000  3378.000  3400.00  4264795

# %%
df.describe().T
# Out:
#          count          mean  ...         75%           max
# open    1257.0  1.388937e+03  ...     1820.00  3.547000e+03
# high    1257.0  1.403222e+03  ...     1831.09  3.552250e+03
# low     1257.0  1.373176e+03  ...     1801.50  3.486685e+03
# close   1257.0  1.389155e+03  ...     1818.51  3.531450e+03
# volume  1257.0  4.266193e+06  ...  5103803.00  1.655260e+07
#
# [5 rows x 8 columns]

# %%
pd.set_option('float_format', '{:.2f}'.format)
df.describe().T
# Out:
#          count       mean        std  ...        50%        75%         max
# open   1257.00    1388.94     642.35  ...    1449.00    1820.00     3547.00
# high   1257.00    1403.22     651.22  ...    1468.94    1831.09     3552.25
# low    1257.00    1373.18     633.43  ...    1424.52    1801.50     3486.68
# close  1257.00    1389.15     642.87  ...    1450.89    1818.51     3531.45
# volume 1257.00 4266193.38 2141863.59  ... 3708851.00 5103803.00 16552598.00
#
# [5 rows x 8 columns]

# %%
df[['open', 'close']]
# Out:
#               open   close
# Date
# 2020-09-02 3547.00 3531.45
# 2020-09-01 3489.58 3499.12
# 2020-08-31 3408.99 3450.96
# 2020-08-28 3423.00 3401.80
# 2020-08-27 3450.05 3400.00
# ...            ...     ...
# 2015-09-14  529.44  521.38
# 2015-09-11  521.07  529.44
# 2015-09-10  515.15  522.24
# 2015-09-09  524.00  516.89
# 2015-09-08  508.69  517.54
#
# [1257 rows x 2 columns]

# %%
df.head()
# Out:
#               open    high     low   close   volume
# Date
# 2020-09-02 3547.00 3552.25 3486.68 3531.45  3931476
# 2020-09-01 3489.58 3513.87 3467.00 3499.12  3476407
# 2020-08-31 3408.99 3495.00 3405.00 3450.96  4185885
# 2020-08-28 3423.00 3433.37 3386.50 3401.80  2896978
# 2020-08-27 3450.05 3453.00 3378.00 3400.00  4264795

# %%
df.iloc[:, [0, -2, -1]]
# Out:
#               open   close   volume
# Date
# 2020-09-02 3547.00 3531.45  3931476
# 2020-09-01 3489.58 3499.12  3476407
# 2020-08-31 3408.99 3450.96  4185885
# 2020-08-28 3423.00 3401.80  2896978
# 2020-08-27 3450.05 3400.00  4264795
# ...            ...     ...      ...
# 2015-09-14  529.44  521.38  3130200
# 2015-09-11  521.07  529.44  3227800
# 2015-09-10  515.15  522.24  2574927
# 2015-09-09  524.00  516.89  4370600
# 2015-09-08  508.69  517.54  3810600
#
# [1257 rows x 3 columns]

# %%
df.head()
# Out:
#               open    high     low   close   volume
# Date
# 2020-09-02 3547.00 3552.25 3486.68 3531.45  3931476
# 2020-09-01 3489.58 3513.87 3467.00 3499.12  3476407
# 2020-08-31 3408.99 3495.00 3405.00 3450.96  4185885
# 2020-08-28 3423.00 3433.37 3386.50 3401.80  2896978
# 2020-08-27 3450.05 3453.00 3378.00 3400.00  4264795

# %%
df.loc["2020-07-31":"2020-07-01"]
# Out:
#               open    high     low   close   volume
# Date
# 2020-07-31 3244.00 3246.82 3151.00 3164.68  8083369
# 2020-07-30 3014.00 3092.00 3005.00 3051.88  6128265
# 2020-07-29 3030.99 3039.16 2996.77 3033.53  2974060
# 2020-07-28 3054.27 3077.09 2995.76 3000.33  3126651
# 2020-07-27 3062.00 3098.00 3015.77 3055.21  4170492
# 2020-07-24 2930.00 3031.58 2888.00 3008.91  5632413
# 2020-07-23 3098.27 3098.27 2970.00 2986.55  5656906
# 2020-07-22 3125.00 3150.00 3065.26 3099.91  4104225
# 2020-07-21 3232.49 3240.58 3105.72 3138.29  6134965
# 2020-07-20 3000.20 3201.36 2994.02 3196.84  7598176
# 2020-07-17 3009.00 3024.00 2948.45 2961.97  4761319
# 2020-07-16 2971.06 3032.00 2918.23 2999.90  6394246
# 2020-07-15 3080.23 3098.35 2973.18 3008.87  5788874
# 2020-07-14 3089.00 3127.38 2950.00 3084.00  7231933
# 2020-07-13 3251.06 3344.29 3068.39 3104.00  7720420
# 2020-07-10 3191.76 3215.00 3135.70 3200.00  5485982
# 2020-07-09 3115.99 3193.88 3074.00 3182.63  6388659
# ...

# %%
df = fetch_financial_data('UBER')
df.head()
# Out:
#             Open  High   Low  Close    Volume
# Date
# 2020-09-02 34.21 34.51 33.29  34.37  16552685
# 2020-09-01 33.45 34.51 33.15  34.30  16026170
# 2020-08-31 33.62 33.92 33.14  33.63  14980621
# 2020-08-28 33.00 33.94 32.82  33.80  17833021
# 2020-08-27 32.40 33.07 32.27  32.80  21306491

# %%
df.describe().T
# Out:
#         count        mean         std  ...         50%         75%          max
# Open   333.00       33.77        5.71  ...       32.73       37.30        46.98
# High   333.00       34.45        5.64  ...       33.32       37.80        47.08
# Low    333.00       32.96        5.72  ...       31.98       36.28        45.08
# Close  333.00       33.73        5.65  ...       32.76       37.01        46.38
# Volume 333.00 24955542.66 20278297.54  ... 20795402.00 32764549.00 186322536.00
#
# [5 rows x 8 columns]

# %%
df['Average'] = (df['Open'] + df['Close']) / 2
df.head()
# Out:
#             Open  High   Low  Close    Volume  Average
# Date
# 2020-09-02 34.21 34.51 33.29  34.37  16552685    34.29
# 2020-09-01 33.45 34.51 33.15  34.30  16026170    33.88
# 2020-08-31 33.62 33.92 33.14  33.63  14980621    33.62
# 2020-08-28 33.00 33.94 32.82  33.80  17833021    33.40
# 2020-08-27 32.40 33.07 32.27  32.80  21306491    32.60

# %%
df['Close_shift'] = df['Close'].shift(1)
df.head()
# Out:
#             Open  High   Low  Close    Volume  Average  Close_shift
# Date
# 2020-09-02 34.21 34.51 33.29  34.37  16552685    34.29          nan
# 2020-09-01 33.45 34.51 33.15  34.30  16026170    33.88        34.37
# 2020-08-31 33.62 33.92 33.14  33.63  14980621    33.62        34.30
# 2020-08-28 33.00 33.94 32.82  33.80  17833021    33.40        33.63
# 2020-08-27 32.40 33.07 32.27  32.80  21306491    32.60        33.80

# %%
df['Daily_change'] = df['Close_shift'] / df['Close'] -1
df.head()
# Out:
#             Open  High   Low  ...  Average  Close_shift  Daily_change
# Date                          ...
# 2020-09-02 34.21 34.51 33.29  ...    34.29          nan           nan
# 2020-09-01 33.45 34.51 33.15  ...    33.88        34.37          0.00
# 2020-08-31 33.62 33.92 33.14  ...    33.62        34.30          0.02
# 2020-08-28 33.00 33.94 32.82  ...    33.40        33.63         -0.01
# 2020-08-27 32.40 33.07 32.27  ...    32.60        33.80          0.03
#
# [5 rows x 8 columns]

# %%
df.columns = [col.lower() for col in df.columns]
df.head()
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-09-02 34.21 34.51 33.29  ...    34.29          nan           nan
# 2020-09-01 33.45 34.51 33.15  ...    33.88        34.37          0.00
# 2020-08-31 33.62 33.92 33.14  ...    33.62        34.30          0.02
# 2020-08-28 33.00 33.94 32.82  ...    33.40        33.63         -0.01
# 2020-08-27 32.40 33.07 32.27  ...    32.60        33.80          0.03
#
# [5 rows x 8 columns]

# %%
df['daily_change'].max()
# Out:
# 0.3825910931174088

# %%
df['daily_change'].min()
# Out:
# -0.21628767847699626

# %%
import seaborn as sns
sns.set()

# %%
_ = df['daily_change'].hist(bins=50)

# %%
df['close'].plot()

# %%
df_positive = df[df['daily_change']>0]
df_positive
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-09-01 33.45 34.51 33.15  ...    33.88        34.37          0.00
# 2020-08-31 33.62 33.92 33.14  ...    33.62        34.30          0.02
# 2020-08-27 32.40 33.07 32.27  ...    32.60        33.80          0.03
# 2020-08-26 31.01 32.71 30.95  ...    31.66        32.80          0.02
# 2020-08-25 31.04 31.19 30.60  ...    31.12        32.30          0.04
# ...          ...   ...   ...  ...      ...          ...           ...
# 2019-05-30 40.07 40.38 39.50  ...    39.94        40.41          0.02
# 2019-05-23 40.80 41.09 40.02  ...    40.63        41.51          0.03
# 2019-05-15 39.37 41.88 38.95  ...    40.33        43.00          0.04
# 2019-05-14 38.31 39.96 36.85  ...    39.14        41.29          0.03
# 2019-05-13 38.79 39.24 36.08  ...    37.95        39.96          0.08
#
# [158 rows x 8 columns]

# %%
df_positive['daily_change'].mean()
# Out:
# 0.028588790658181217

# %%
df_positive.size
# Out:
# 1264

# %%
df_positive['daily_change'].mean()
# Out:
# 0.028588790658181217

# %%
df_negative = df[df['daily_change'] < 0]

# %%
df_negative.size
# Out:
# 1368

# %%
df_negative['daily_change'].mean()
# Out:
# -0.025781713788173965

# %%
df['close'] == df['high']
# Out:
# Date
# 2020-09-02    False
# 2020-09-01    False
# 2020-08-31    False
# 2020-08-28    False
# 2020-08-27    False
#               ...
# 2019-05-16    False
# 2019-05-15    False
# 2019-05-14     True
# 2019-05-13    False
# 2019-05-10    False
# Length: 333, dtype: bool

# %%
df[df['close'] == df['high']]
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-08-25 31.04 31.19 30.60  ...    31.12        32.30          0.04
# 2019-05-24 41.28 41.51 40.50  ...    41.39        40.95         -0.01
# 2019-05-14 38.31 39.96 36.85  ...    39.14        41.29          0.03
#
# [3 rows x 8 columns]

# %%
df[df['close'] == df['low']]
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2019-12-27 30.80 31.06 30.17  ...    30.48        29.74         -0.01
# 2019-12-09 27.96 28.36 27.68  ...    27.82        27.89          0.01
# 2019-08-12 39.84 39.95 37.00  ...    38.42        36.45         -0.01
#
# [3 rows x 8 columns]

# %%
df.index >= '2020-01-01'
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df[df.index >= '2020-01-01']
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-09-02 34.21 34.51 33.29  ...    34.29          nan           nan
# 2020-09-01 33.45 34.51 33.15  ...    33.88        34.37          0.00
# 2020-08-31 33.62 33.92 33.14  ...    33.62        34.30          0.02
# 2020-08-28 33.00 33.94 32.82  ...    33.40        33.63         -0.01
# 2020-08-27 32.40 33.07 32.27  ...    32.60        33.80          0.03
# ...          ...   ...   ...  ...      ...          ...           ...
# 2020-01-08 32.73 34.52 32.46  ...    33.33        33.97          0.00
# 2020-01-07 31.79 32.84 31.36  ...    32.30        33.93          0.03
# 2020-01-06 31.01 32.06 31.00  ...    31.30        32.81          0.04
# 2020-01-03 30.62 31.43 30.48  ...    31.00        31.58          0.01
# 2020-01-02 29.94 31.00 29.79  ...    30.46        31.37          0.01
#
# [170 rows x 8 columns]

# %%
df[(df.index >='2020-01-01') & (df.index < '2020-06-01')]
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-05-29 34.18 36.45 34.00  ...    35.25        35.82         -0.01
# 2020-05-28 34.90 35.10 33.82  ...    34.52        36.32          0.06
# 2020-05-27 34.42 35.00 33.10  ...    34.65        34.15         -0.02
# 2020-05-26 35.97 36.00 34.50  ...    35.27        34.88          0.01
# 2020-05-22 34.15 34.93 33.57  ...    34.49        34.56         -0.01
# ...          ...   ...   ...  ...      ...          ...           ...
# 2020-01-08 32.73 34.52 32.46  ...    33.33        33.97          0.00
# 2020-01-07 31.79 32.84 31.36  ...    32.30        33.93          0.03
# 2020-01-06 31.01 32.06 31.00  ...    31.30        32.81          0.04
# 2020-01-03 30.62 31.43 30.48  ...    31.00        31.58          0.01
# 2020-01-02 29.94 31.00 29.79  ...    30.46        31.37          0.01
#
# [103 rows x 8 columns]

# %%
df.index.month == 3
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df[df.index.month == 3]
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-03-31 27.75 28.25 26.92  ...    27.84        25.42         -0.09
# 2020-03-30 26.33 28.39 25.31  ...    27.08        27.92          0.00
# 2020-03-27 25.82 28.03 25.07  ...    26.55        27.83          0.02
# 2020-03-26 26.60 28.44 25.78  ...    27.36        27.28         -0.03
# 2020-03-25 26.18 28.45 25.31  ...    26.19        28.12          0.07
# 2020-03-24 24.41 26.84 23.59  ...    25.40        26.19         -0.01
# 2020-03-23 21.07 22.73 19.73  ...    21.73        26.39          0.18
# 2020-03-20 22.53 23.89 20.61  ...    21.93        22.40          0.05
# 2020-03-19 15.96 21.26 15.70  ...    18.23        21.33          0.04
# 2020-03-18 17.76 17.80 13.71  ...    16.29        20.49          0.38
# 2020-03-17 20.18 20.31 18.01  ...    19.55        14.82         -0.22
# 2020-03-16 20.15 21.49 19.10  ...    20.22        18.91         -0.07
# ...

# %%
df[df.index.day == 1]
# Out:
#             open  high   low  ...  average  close_shift  daily_change
# Date                          ...
# 2020-09-01 33.45 34.51 33.15  ...    33.88        34.37          0.00
# 2020-07-01 30.96 31.27 30.16  ...    30.70        30.68          0.01
# 2020-06-01 35.64 36.39 35.16  ...    35.73        35.81         -0.00
# 2020-05-01 29.13 29.72 28.32  ...    28.76        27.42         -0.03
# 2020-04-01 26.50 26.77 24.81  ...    25.96        23.68         -0.07
# 2019-11-01 31.45 31.70 30.74  ...    31.41        31.08         -0.01
# 2019-10-01 30.37 30.51 28.65  ...    29.76        29.00         -0.01
# 2019-08-01 42.14 42.54 41.00  ...    41.73        40.40         -0.02
# 2019-07-01 46.98 47.04 44.06  ...    45.62        44.00         -0.01
#
# [9 rows x 8 columns]
