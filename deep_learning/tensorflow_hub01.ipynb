# %% [markdown]
# <a href="https://colab.research.google.com/github/danlig94/data_science/blob/master/deep_learning/tensorflow_hub01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import PIL.Image as Image
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
clf_url ="https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4"

IMAGE_SHAPE = (224, 224)

clf = tf.keras.Sequential([
    hub.KerasLayer(clf_url, input_shape=IMAGE_SHAPE+(3,))
])

# %%
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())
imagenet_labels
# Out:
# ...
# 16384/10484 [==============================================] - 0s 0us/step
# array(['background', 'tench', 'goldfish', ..., 'bolete', 'ear',
#        'toilet tissue'], dtype='<U30')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b7d8757d-377d-400a-b70b-120a34b6d986" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7d8757d-377d-400a-b70b-120a34b6d986">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iphone-w-dloni.jpg to iphone-w-dloni.jpg

# %%
filename = list(uploaded.keys())[0]
img = Image.open(filename).resize(IMAGE_SHAPE)
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA7A2B96E10>

# %%
img_arr = np.array(img) / 255.0
img_arr = np.expand_dims(img_arr, axis=0)
result = clf.predict(img_arr)
predicted_class = np.argmax(result[0], axis=-1)
predicted_class_name = imagenet_labels[predicted_class]
predicted_class_name
# Out:
# 'remote control'

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread(filename)
text = f'class: {predicted_class_name}'
img = cv2.putText(img=img, text=text, org=(10, 30), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1, color=(0, 255, 0), thickness=2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=928x535 at 0x7FA79651DF60>
